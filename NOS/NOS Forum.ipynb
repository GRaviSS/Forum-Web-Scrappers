# %% [markdown]
# ### Scrapping NOS Forum

# %%
import requests
import re
import json
import logging
import pandas
from collections import OrderedDict
from bs4 import BeautifulSoup
from selenium import webdriver
import pandas as pd
import numpy as np
import time
import logging
from collections import OrderedDict
from tqdm import tqdm_notebook as tqdm
from random import seed
from random import randint
from datetime import datetime
from webdriver_manager.chrome import ChromeDriverManager
from time import time       # Other imports
from time import sleep
import csv
import time
from tqdm import tqdm_notebook as tqdm
from random import seed
from random import randint
from datetime import datetime
from selenium import webdriver
from urllib.request import urlopen
import json
from pandas.io.json import json_normalize
import pandas as pd, numpy as np
from time import sleep

# %% [markdown]
# ### Drivers

# %%
driver = webdriver.Chrome("C:/Users/GSantos/Documents/GABRIEL RAVI/Web Scrapping/chromedriver_win32_2/chromedriver.exe")

# %%
driver.get("https://forum.nos.pt/search/activity/recent")

# %%
content = driver.page_source
soup = BeautifulSoup(content)

# %%
base_url = "https://forum.meo.pt/"

# %% [markdown]
# ### Scroll Down

# %%
from time import sleep
def scroll_down(driver) -> None:
        """Scrolling down the page and taking the URLs"""
        global listona
        global posts_url
        
        listona = []
        listona2 = []
        posts_url = []
        last_height = 0
        
        while True:
            driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
            sleep(3)
            
            
            elements = driver.find_elements_by_class_name('topic-view_link')
            for elem in elements:
                urls = elem.get_attribute('href')
                listona.append(urls)    
                
                
                
            new_height = driver.execute_script("return document.body.scrollHeight")
            
            if new_height == last_height:
                break
            last_height = new_height
            
            posts_url += listona

# %%
scroll_down(driver)

# %%
posts_url
# Out:
# ['https://forum.nos.pt/gerir-produtos-e-servicos-18/playstation-23075',
#  'https://forum.nos.pt/utilizar-a-internet-fixa-e-movel-4/falhas-de-internet-23901',
#  'https://forum.nos.pt/utilizar-a-internet-fixa-e-movel-4/servico-de-internet-fixo-e-wifi-21016',
#  'https://forum.nos.pt/gerir-produtos-e-servicos-18/tarifario-wtf-apple-watch-22967',
#  'https://forum.nos.pt/ver-televisao-em-casa-5/o-tvcine-chegou-a-nos-22403',
#  'https://forum.nos.pt/nos-tv-44/ntv133-ntv134-22160',
#  'https://forum.nos.pt/gerir-produtos-e-servicos-18/especial-clientes-nos-quem-e-especial-merece-um-grande-desconto-19099',
#  'https://forum.nos.pt/ver-televisao-em-casa-5/canal-panda-desapareceu-24022',
#  'https://forum.nos.pt/gerir-produtos-e-servicos-18/desativacao-tvcine-agendada-23922',
#  'https://forum.nos.pt/gerir-produtos-e-servicos-18/estado-da-encomenda-24026',
#  'https://forum.nos.pt/ver-televisao-em-casa-5/uma-box-feita-para-si-14220',
#  'https://forum.nos.pt/nos-wi-fi-46/inicio-de-sessao-no-nos-wi-fi-24025',
#  'https://forum.nos.pt/utilizar-a-internet-fixa-e-movel-4/internet-muito-lenta-como-posso-resolver-24011',
#  'https://forum.nos.pt/gerir-produtos-e-servicos-18/oferta-adesao-23845',
#  'https://forum.nos.pt/utilizar-a-internet-fixa-e-movel-4/adesao-ao-servico-kanguru-pos-pago-problemas-24024',
#  'https://forum.nos.pt/utilizar-a-internet-fixa-e-movel-4/conheca-o-novo-giga-router-12340',
#  'https://forum.nos.pt/novidades-16/videoclube-novidades-e-promocoes-de-primavera-24006',
#  'https://forum.nos.pt/gerir-produtos-e-servicos-18/estafeta-ou-tecnico-em-pleno-covid-23919',
#  'https://forum.nos.pt/utilizar-a-internet-fixa-e-movel-4/hotspot-nos-com-as-4-luzes-ligadas-16692',
#  'https://forum.nos.pt/sou-novo-na-nos-17/reclamacao-reposicao-24023',
#  'https://forum.nos.pt/nos-tv-44/erro-app-nos-tv-24021',
#  'https://forum.nos.pt/novidades-16/ajude-nos-a-melhorar-a-apple-tv-23962',
#  'https://forum.nos.pt/utilizar-a-internet-fixa-e-movel-4/como-ligar-um-equipamento-ao-router-por-wps-13144',
#  'https://forum.nos.pt/ver-televisao-em-casa-5/alteracoes-na-grelha-nos-12126',
#  'https://forum.nos.pt/gerir-produtos-e-servicos-18/oferta-de-adesao-24020']

# %% [markdown]
# ### Coletando Informações do Post

# %%
# Exemplo com 3 comentários
driver.get("https://forum.nos.pt/utilizar-a-internet-fixa-e-movel-4/instalacao-pdo-24014")

# %%
type_post_principal = driver.find_element_by_xpath('/html/body/main/div[3]/div/ul/li[3]/a').text

# %%
def info_post():
    
    global type_post_principal
    global title_post_principal
    global user_post_principal
    global class_user_principal
    global data_post_principal
    global texto_post_principal
    global likes_post_principal
    
    
    ### Category of the post
    try:
        type_post_principal = driver.find_element_by_xpath('/html/body/main/div[3]/div/ul/li[3]/a').text
    except:
        pass
    if type_post_principal == ['']:
        type_post_principal = ["NaN"]   
    
    ### Title of the post
    try:
        title_post_principal = driver.find_element_by_css_selector('body > main > div.full-width.Template-content > div > div.col.col--main.has--side.qa-div-main > div > div > div.box.qa-topic-first-post > header > h1').text
    except:
        pass
    if title_post_principal == ['']:
        title_post_principal = ["NaN"]   
    
    ### User of the post
    try:
        user_post_principal = driver.find_element_by_xpath('/html/body/main/div[5]/div/div[1]/div/div/div[1]/div[2]/div[2]/ul/li[1]/div/a').text
    except:
        pass
    if user_post_principal == ['']:
        user_post_principal = ["NaN"]   
    
    ### Class of the Userthat posted
    try:
        class_user_principal = driver.find_element_by_css_selector('.usertitle.qa-usertitle').text
    except:
        pass
    if class_user_principal == ['']:
        class_user_principal = ["NaN"]   
    
    ### Data Post
    try:
        data_post_principal = driver.find_element_by_css_selector('.tooltip-trigger.js-tooltip-trigger.qa-latest-post-time').get_attribute('datetime')
    except:
        pass
    if data_post_principal == ['']:
        data_post_principal = ["NaN"]   
    
    ### Post itself
    try:
        texto_post_principal = driver.find_element_by_xpath('/html/body/main/div[5]/div/div[1]/div/div/div[1]/div[2]/div[3]').text.replace("\n"," ")
    except:
        pass
    if texto_post_principal == ['']:
        texto_post_principal = ["NaN"]   
    
    ### Likes of the post
    try:
        likes_post_principal = driver.find_element_by_xpath('/html/body/main/div[5]/div/div[1]/div/div/div[1]/div[2]/div[4]/div[2]/div/div[2]/div/span').text
    except:
        pass
    if likes_post_principal == ['']:
        likes_post_principal = ["NaN"]

# %%
likes_post_principal = driver.find_element_by_xpath('/html/body/main/div[5]/div/div[1]/div/div/div[1]/div[2]/div[4]/div[2]/div/div[2]/div/span')
likes_post_principal.text
# Out:
# '1 pessoa gostou'

# %%
info_post()
type_post_principal
title_post_principal
user_post_principal
class_user_principal
data_post_principal
texto_post_principal

likes_post_principal
# Out:
# '1 pessoa gostou'

# %% [markdown]
# ### Collecting all the answers

# %%
def scrap_comments():
    
    global user_posts
    global users_post2
    global class_users
    global class_users2
    global data_posts
    global data_posts2
    global texto_posts
    global texto_posts2
    global likes_posts
    global likes_post2
    
    user_posts = []
    users_post2 = []
    class_users = []
    class_users2 = []
    data_posts = []
    data_posts2 = []
    texto_posts = []
    texto_posts2 = []
    likes_post = []
    likes_post2 = []
    
    u_post = driver.find_elements_by_class_name('group--inline')
    cu_post = driver.find_elements_by_css_selector('.usertitle.qa-usertitle')
    post_date = driver.find_elements_by_xpath("//a[@class='post__date']/div/time")
    texto_post = driver.find_elements_by_css_selector('.post__content.js-content--original.qa-topic-post-content.post__content--new-editor')
    likes_u_post = driver.find_elements_by_css_selector('.link.link--quiet.icon--b.icon--thumb-up.qa-like-link.post__action-link')

    
    for i in u_post:
        user_posts.append(i.text)
    
    for i in cu_post:
        class_users.append(i.text)
    
    for i in post_date:
        data_posts.append(i.get_attribute('datetime'))
    data_posts.insert(0, data_post_principal) 
    for i in texto_post:
        texto_posts.append(i.text.replace("\n"," "))
   
    for i in likes_u_post:
        likes_post.append(i.text)#.replace("likes"," ")
    
    
    users_post2 += user_posts
    class_users2 += class_users
    data_posts2 += data_posts
    texto_posts2 += texto_posts
    likes_post2 += likes_post

# %%
data_posts2
# Out:
# 15

# %%
user_posts = []
users_post2 = []

# %%
scrap_comments()
print(len(users_post2))
print(len(class_users2))
print(len(data_posts2))
print(len(texto_posts2))
print(len(likes_post2))
# Out:
# 16
# 16
# 16
# 16
# 16

# %% [markdown]
# ### Function to add the data

# %%
from time import time

# %%
start_time = time()

post_data = OrderedDict()

post_data['Tempo_recolha'] = []
post_data['Categoria'] = []
post_data['Empresa'] = []
post_data['n'] = []
post_data['URL_Post'] = []
post_data['Texto_Pub'] = []
post_data['Theme_Pub'] = []
post_data['User_Pub'] = []
post_data['Class_User_Pub'] = []
post_data['Data_Pub'] = []
post_data['Texto_Pub'] = []
post_data['Likes_Pub'] = []

post_data['User_Conv'] = []
post_data['Class_Conv'] = []
post_data['Data_Conv'] = []
post_data['Textos_Conv'] = []
post_data['Likes_Conv'] = []

post_data['N_respostas'] = []

#post_data['Autor_Post_ID'] = []

# %% [markdown]
# ## Create the List

# %%
base_url1 = 'https://forum.nos.pt/search/activity/recent/index'
base_url2 = '.html'
empresa= 'NOS'
N = 20
categoria = "Telecomunicação"

lista = pd.DataFrame({ 'N' : range(1, N + 1 ,1),
                      'Categoria': categoria,
                     "URL_Post1": base_url1,
                     "URL_Post2": base_url2,
                     "Empresa": empresa})


lista["posts"] = lista["URL_Post1"] + lista["N"].astype(str) + lista["URL_Post2"] 
lista = lista.drop(columns=['URL_Post1', 'URL_Post2'])
lista
# Out:
#      N        Categoria Empresa  \
# 0    1  Telecomunicação     NOS
# 1    2  Telecomunicação     NOS
# 2    3  Telecomunicação     NOS
# 3    4  Telecomunicação     NOS
# 4    5  Telecomunicação     NOS
# 5    6  Telecomunicação     NOS
# 6    7  Telecomunicação     NOS
# 7    8  Telecomunicação     NOS
# 8    9  Telecomunicação     NOS
# 9   10  Telecomunicação     NOS
# 10  11  Telecomunicação     NOS
# 11  12  Telecomunicação     NOS
# 12  13  Telecomunicação     NOS
# 13  14  Telecomunicação     NOS
# 14  15  Telecomunicação     NOS
# 15  16  Telecomunicação     NOS
# 16  17  Telecomunicação     NOS
# 17  18  Telecomunicação     NOS
# 18  19  Telecomunicação     NOS
# 19  20  Telecomunicação     NOS
#
#                                                 posts
# 0   https://forum.nos.pt/search/activity/recent/in...
# 1   https://forum.nos.pt/search/activity/recent/in...
# 2   https://forum.nos.pt/search/activity/recent/in...
# 3   https://forum.nos.pt/search/activity/recent/in...
# 4   https://forum.nos.pt/search/activity/recent/in...
# 5   https://forum.nos.pt/search/activity/recent/in...
# 6   https://forum.nos.pt/search/activity/recent/in...
# 7   https://forum.nos.pt/search/activity/recent/in...
# 8   https://forum.nos.pt/search/activity/recent/in...
# 9   https://forum.nos.pt/search/activity/recent/in...
# 10  https://forum.nos.pt/search/activity/recent/in...
# 11  https://forum.nos.pt/search/activity/recent/in...
# 12  https://forum.nos.pt/search/activity/recent/in...
# 13  https://forum.nos.pt/search/activity/recent/in...
# 14  https://forum.nos.pt/search/activity/recent/in...
# 15  https://forum.nos.pt/search/activity/recent/in...
# 16  https://forum.nos.pt/search/activity/recent/in...
# 17  https://forum.nos.pt/search/activity/recent/in...
# 18  https://forum.nos.pt/search/activity/recent/in...
# 19  https://forum.nos.pt/search/activity/recent/in...

# %%
# lista["posts"][3]
lista["posts"][10]
# Out:
# 'https://forum.nos.pt/search/activity/recent/index11.html'

# %% [markdown]
# ## Here comes the Magic

# %%
from tqdm.notebook import tqdm

# %%
posts_url = []

# %%
if __name__ == "__main__":
    
    size_ = 0
    with tqdm(total=len(lista["posts"][:1])) as pbar:
        for company, lista_posts in enumerate(lista["posts"][:1], start=0):
            
            pbar.set_description(f'Tamanho da base: {size_} obs')
            pbar.update(1)
            
            driver.get(lista_posts)
            
            scroll_down(driver)
            
            page_source = driver.page_source
            profile_bs = BeautifulSoup(page_source, 'lxml')

            company_ = lista["Empresa"][company]
            
            with tqdm(total=len(posts_url)) as pbar2:
                    for n, i in enumerate(posts_url, start=1):
                        pbar2.update(1)
                        pbar2.set_description(f'Posts da {company_}')
                                                
                        driver.get(i)
                        
                        info_post()                   
                                                
                        driver.get(i)
                        
                        user_post = []
                        class_users = []
                        data_posts = []
                        texto_posts = []
                        likes_post = []
                        
                        comment_url2 = []
                        user_post2 = []
                        class_users2 = []
                        data_posts2 = []
                        texto_posts2 = []
                        likes_post2 = []
                        
                        scrap_comments()
                                                
                           
                        while len(driver.find_elements_by_xpath("//*[contains(@aria-label,'Load more comments')]")) == 1:

                            page_source = driver.page_source
                            profile_bs = BeautifulSoup(page_source, 'lxml')

                            comment_url_aux = []

                            elements = driver.find_elements_by_css_selector('.page-link.lia-link-navigation.lia-custom-event')


                            for elem in elements:
                                urls = elem.get_attribute('href')
                                comment_url_aux.append(urls)  


                            if comment_url_aux == []:
                                break

    #                         driver.get(comment_url_aux)

    #                         scrap_comments()

                            if len(texto_posts2) == 0:
                                    users_post2, class_users2, data_posts2, texto_posts2,likes_post2 = ["NaN"], ["NaN"], ["NaN"], ["NaN"], ["NaN"]


                        comment_comment = comment_url2
                        if len(comment_url2) > 0:
                            for comment_count, aux in enumerate(comment_comment,start=0):
                                comment_url2 = []
                                driver.get(comment_comment[comment_count])
                                scrap_comments()

                                    
                        post_data['Tempo_recolha'] = np.concatenate((post_data['Tempo_recolha'], np.tile(datetime.now(), len(texto_posts2))))
                        post_data['Categoria'] = np.concatenate((post_data['Categoria'], np.tile(lista['Categoria'][company], len(texto_posts2))))
                        post_data['Empresa'] = np.concatenate((post_data['Empresa'], np.tile(lista['Empresa'][company], len(texto_posts2))))
       #                 post_data['post_author_url'] = np.concatenate((post_data['post_author_url'], np.tile(lista['URL_Post'][company], len(texto_posts2))))
                        post_data['n'] = np.concatenate((post_data['n'], np.tile(n, len(texto_posts2))))
                        post_data['URL_Post'] = np.concatenate((post_data['URL_Post'], np.tile(i, len(texto_posts2))))

                        post_data['Texto_Pub'] = np.concatenate((post_data['Texto_Pub'], np.tile(texto_post_principal, len(texto_posts2))))
                        post_data['Theme_Pub'] = np.concatenate((post_data['Theme_Pub'], np.tile(title_post_principal, len(texto_posts2))))
                        post_data['User_Pub'] = np.concatenate((post_data['User_Pub'], np.tile(user_post_principal, len(texto_posts2))))
                        post_data['Class_User_Pub'] = np.concatenate((post_data['Class_User_Pub'], np.tile(class_user_principal, len(texto_posts2))))
                        post_data['Data_Pub'] = np.concatenate((post_data['Data_Pub'], np.tile(data_post_principal, len(texto_posts2))))
                        post_data['Likes_Pub'] = np.concatenate((post_data['Likes_Pub'], np.tile(likes_post_principal, len(texto_posts2))))
                    
                    
                        size_ = len(post_data['URL_Post'])

                        post_data['User_Conv'] = post_data['User_Conv'] + users_post2
                        post_data['Class_Conv'] = post_data['Class_Conv'] + class_users2
                        post_data['Data_Conv'] = post_data['Data_Conv'] + data_posts2
                        post_data['Textos_Conv'] = post_data['Textos_Conv'] + texto_posts2
                        post_data['Likes_Conv'] = post_data['Likes_Conv'] + likes_post2
# Out:
# <ipython-input-246-db9d51aab9f8>:4: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   with tqdm(total=len(lista["posts"][:1])) as pbar:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=1.0), HTML(value='')))
# <ipython-input-246-db9d51aab9f8>:19: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   with tqdm(total=len(posts_url)) as pbar2:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=25.0), HTML(value='')))

# %%
post_data['Texto_Pub']
# Out:
# array(['Boa noite,  o meu telefone fixo avariou. Mandei um familiar ligar à NOS e até agora nada, apesar de terem o meu numero de telemovel. O que devo fazer mais?  MC Elísia Tavarres',
#        'Boa noite,  o meu telefone fixo avariou. Mandei um familiar ligar à NOS e até agora nada, apesar de terem o meu numero de telemovel. O que devo fazer mais?  MC Elísia Tavarres',
#        'Boa noite,  o meu telefone fixo avariou. Mandei um familiar ligar à NOS e até agora nada, apesar de terem o meu numero de telemovel. O que devo fazer mais?  MC Elísia Tavarres',
#        'Boa noite,  o meu telefone fixo avariou. Mandei um familiar ligar à NOS e até agora nada, apesar de terem o meu numero de telemovel. O que devo fazer mais?  MC Elísia Tavarres',
#        'Boa noite,  o meu telefone fixo avariou. Mandei um familiar ligar à NOS e até agora nada, apesar de terem o meu numero de telemovel. O que devo fazer mais?  MC Elísia Tavarres',
#        'Boa noite,  o meu telefone fixo avariou. Mandei um familiar ligar à NOS e até agora nada, apesar de terem o meu numero de telemovel. O que devo fazer mais?  MC Elísia Tavarres',
#        'Boa noite,  o meu telefone fixo avariou. Mandei um familiar ligar à NOS e até agora nada, apesar de terem o meu numero de telemovel. O que devo fazer mais?  MC Elísia Tavarres',
#        'Boa noite,  o meu telefone fixo avariou. Mandei um familiar ligar à NOS e até agora nada, apesar de terem o meu numero de telemovel. O que devo fazer mais?  MC Elísia Tavarres',
#        'Boa noite,  o meu telefone fixo avariou. Mandei um familiar ligar à NOS e até agora nada, apesar de terem o meu numero de telemovel. O que devo fazer mais?  MC Elísia Tavarres',
#        'Boa noite,  o meu telefone fixo avariou. Mandei um familiar ligar à NOS e até agora nada, apesar de terem o meu numero de telemovel. O que devo fazer mais?  MC Elísia Tavarres',
#        'Boa noite,  o meu telefone fixo avariou. Mandei um familiar ligar à NOS e até agora nada, apesar de terem o meu numero de telemovel. O que devo fazer mais?  MC Elísia Tavarres',
#        'ao chegar a casa liguei a box,funciona através de parabolica,e tinha os canais todos codificados liguei para a assistência técnica (através de um 91.......) depois de varios testes solicitados pelo colaborador da NOS ,tipo desligue a box,tire a corrente,tire cartão,aguarde um momento,bem por fim lá conseguiram me resolver o problema ,no final do mês paguei dessa chamada 9,90 euros foi no dia 17 de junho pergunto agora quem me paga esta chamada,e voltou acontecer o mesmo em julho estou para ver o tombo,desloquei me á loja da Boavista e disseram me que nâo me podiam fazer nada que liga se para a faturação ,do meu telefone nem pensar agradecia que me responde sem a isto,obrigado icon Melhor resposta por Oscar7 Tens telefone fixo da nos? Se tiveres as chamadas para o apoio técnico são grátis. Ver pergunta inicial',
#        'ao chegar a casa liguei a box,funciona através de parabolica,e tinha os canais todos codificados liguei para a assistência técnica (através de um 91.......) depois de varios testes solicitados pelo colaborador da NOS ,tipo desligue a box,tire a corrente,tire cartão,aguarde um momento,bem por fim lá conseguiram me resolver o problema ,no final do mês paguei dessa chamada 9,90 euros foi no dia 17 de junho pergunto agora quem me paga esta chamada,e voltou acontecer o mesmo em julho estou para ver o tombo,desloquei me á loja da Boavista e disseram me que nâo me podiam fazer nada que liga se para a faturação ,do meu telefone nem pensar agradecia que me responde sem a isto,obrigado icon Melhor resposta por Oscar7 Tens telefone fixo da nos? Se tiveres as chamadas para o apoio técnico são grátis. Ver pergunta inicial',
#        'ao chegar a casa liguei a box,funciona através de parabolica,e tinha os canais todos codificados liguei para a assistência técnica (através de um 91.......) depois de varios testes solicitados pelo colaborador da NOS ,tipo desligue a box,tire a corrente,tire cartão,aguarde um momento,bem por fim lá conseguiram me resolver o problema ,no final do mês paguei dessa chamada 9,90 euros foi no dia 17 de junho pergunto agora quem me paga esta chamada,e voltou acontecer o mesmo em julho estou para ver o tombo,desloquei me á loja da Boavista e disseram me que nâo me podiam fazer nada que liga se para a faturação ,do meu telefone nem pensar agradecia que me responde sem a isto,obrigado icon Melhor resposta por Oscar7 Tens telefone fixo da nos? Se tiveres as chamadas para o apoio técnico são grátis. Ver pergunta inicial',
#        'ao chegar a casa liguei a box,funciona através de parabolica,e tinha os canais todos codificados liguei para a assistência técnica (através de um 91.......) depois de varios testes solicitados pelo colaborador da NOS ,tipo desligue a box,tire a corrente,tire cartão,aguarde um momento,bem por fim lá conseguiram me resolver o problema ,no final do mês paguei dessa chamada 9,90 euros foi no dia 17 de junho pergunto agora quem me paga esta chamada,e voltou acontecer o mesmo em julho estou para ver o tombo,desloquei me á loja da Boavista e disseram me que nâo me podiam fazer nada que liga se para a faturação ,do meu telefone nem pensar agradecia que me responde sem a isto,obrigado icon Melhor resposta por Oscar7 Tens telefone fixo da nos? Se tiveres as chamadas para o apoio técnico são grátis. Ver pergunta inicial',
#        'ao chegar a casa liguei a box,funciona através de parabolica,e tinha os canais todos codificados liguei para a assistência técnica (através de um 91.......) depois de varios testes solicitados pelo colaborador da NOS ,tipo desligue a box,tire a corrente,tire cartão,aguarde um momento,bem por fim lá conseguiram me resolver o problema ,no final do mês paguei dessa chamada 9,90 euros foi no dia 17 de junho pergunto agora quem me paga esta chamada,e voltou acontecer o mesmo em julho estou para ver o tombo,desloquei me á loja da Boavista e disseram me que nâo me podiam fazer nada que liga se para a faturação ,do meu telefone nem pensar agradecia que me responde sem a isto,obrigado icon Melhor resposta por Oscar7 Tens telefone fixo da nos? Se tiveres as chamadas para o apoio técnico são grátis. Ver pergunta inicial',
#        'ao chegar a casa liguei a box,funciona através de parabolica,e tinha os canais todos codificados liguei para a assistência técnica (através de um 91.......) depois de varios testes solicitados pelo colaborador da NOS ,tipo desligue a box,tire a corrente,tire cartão,aguarde um momento,bem por fim lá conseguiram me resolver o problema ,no final do mês paguei dessa chamada 9,90 euros foi no dia 17 de junho pergunto agora quem me paga esta chamada,e voltou acontecer o mesmo em julho estou para ver o tombo,desloquei me á loja da Boavista e disseram me que nâo me podiam fazer nada que liga se para a faturação ,do meu telefone nem pensar agradecia que me responde sem a isto,obrigado icon Melhor resposta por Oscar7 Tens telefone fixo da nos? Se tiveres as chamadas para o apoio técnico são grátis. Ver pergunta inicial',
#        'ao chegar a casa liguei a box,funciona através de parabolica,e tinha os canais todos codificados liguei para a assistência técnica (através de um 91.......) depois de varios testes solicitados pelo colaborador da NOS ,tipo desligue a box,tire a corrente,tire cartão,aguarde um momento,bem por fim lá conseguiram me resolver o problema ,no final do mês paguei dessa chamada 9,90 euros foi no dia 17 de junho pergunto agora quem me paga esta chamada,e voltou acontecer o mesmo em julho estou para ver o tombo,desloquei me á loja da Boavista e disseram me que nâo me podiam fazer nada que liga se para a faturação ,do meu telefone nem pensar agradecia que me responde sem a isto,obrigado icon Melhor resposta por Oscar7 Tens telefone fixo da nos? Se tiveres as chamadas para o apoio técnico são grátis. Ver pergunta inicial',
#        'ao chegar a casa liguei a box,funciona através de parabolica,e tinha os canais todos codificados liguei para a assistência técnica (através de um 91.......) depois de varios testes solicitados pelo colaborador da NOS ,tipo desligue a box,tire a corrente,tire cartão,aguarde um momento,bem por fim lá conseguiram me resolver o problema ,no final do mês paguei dessa chamada 9,90 euros foi no dia 17 de junho pergunto agora quem me paga esta chamada,e voltou acontecer o mesmo em julho estou para ver o tombo,desloquei me á loja da Boavista e disseram me que nâo me podiam fazer nada que liga se para a faturação ,do meu telefone nem pensar agradecia que me responde sem a isto,obrigado icon Melhor resposta por Oscar7 Tens telefone fixo da nos? Se tiveres as chamadas para o apoio técnico são grátis. Ver pergunta inicial',
#        'ao chegar a casa liguei a box,funciona através de parabolica,e tinha os canais todos codificados liguei para a assistência técnica (através de um 91.......) depois de varios testes solicitados pelo colaborador da NOS ,tipo desligue a box,tire a corrente,tire cartão,aguarde um momento,bem por fim lá conseguiram me resolver o problema ,no final do mês paguei dessa chamada 9,90 euros foi no dia 17 de junho pergunto agora quem me paga esta chamada,e voltou acontecer o mesmo em julho estou para ver o tombo,desloquei me á loja da Boavista e disseram me que nâo me podiam fazer nada que liga se para a faturação ,do meu telefone nem pensar agradecia que me responde sem a isto,obrigado icon Melhor resposta por Oscar7 Tens telefone fixo da nos? Se tiveres as chamadas para o apoio técnico são grátis. Ver pergunta inicial',
#        'Tenho um router Kanguru e mesmo na zona de Lisboa tenho velocidades de 4 5 MBPs',
#        'Tenho um router Kanguru e mesmo na zona de Lisboa tenho velocidades de 4 5 MBPs',
#        'Boa tarde, sou cliente da NOS a pouco tempo, no dia que instalei o serviço da NOS  disseram que vou receber uma mensagem depois da qual vou poder mudar de cartão SIM. Já passou uma semana e ainda não recebi mensagem nenhuma, apesar de já ter o serviço de Wi-Fi e TV em casa... Alguém me consegue explicar alguma coisa? ',
#        'Boa tarde, sou cliente da NOS a pouco tempo, no dia que instalei o serviço da NOS  disseram que vou receber uma mensagem depois da qual vou poder mudar de cartão SIM. Já passou uma semana e ainda não recebi mensagem nenhuma, apesar de já ter o serviço de Wi-Fi e TV em casa... Alguém me consegue explicar alguma coisa? ',
#        'Conheça o GiGA Router  Fique a saber tudo sobre o GiGA Router, que marca a aposta continua da NOS na evolução tecnológica. Em três versões diferentes, permite velocidades até 1Gb/s, tem Dual band norma AC, Wave2 e MIMO 4x4.   O GiGA Router apresenta como funcionalidades avançadas: Wi-Fi mais rápido, as 4x4 antenas integradas no router permitem atingir velocidades ultrarrápidas Velocidade máxima, velocidade até 1Gbps de download Airtime fairness, garante o mesmo tempo de transmissão a todos os equipamentos ligados por Wi-Fi ao Router, permitindo uma maior performance Beamforming, concentra e dirige o sinal Wi-Fi para onde estão ligados os equipamentos, melhorando o alcance e a velocidade Melhor performance e mais equipamentos ligados, até 50 equipamentos ligados ao mesmo tempo sem perder performance Funcionalidades avançadas, com a App NOS Net é possível controlar a Internet do router em qualquer lugar Gaming e Streaming, ideal para os mais exigentes que valorizam Gaming, streaming de vídeos HD e partilha de conteúdos de grandes dimensões   Para os nossos utilizadores mais técnicos, partilhamos também as principais características do novo GiGa Router: Wi-Fi Dual band 2,4/5GHz, 2,4GHz 802.11 b/g/n com MIMO 3x3 e 5GHz 802.11 a/n/ac Wave2 MU-MIMO 4x4 4 portas LAN (Ethernet) para acesso à internet por cabo 2 entradas telefónicas Porta USB 3.0 Botão para emparelhar Wi-Fi Botão de reset Indicador luminoso de estado   Saiba aqui mais sobre o GiGA Router. Conheça ainda em detalhe os três equipamentos aqui.  Já utilizou o GiGA Router? Partilhe connosco a sua experiência! :)  ',
#        'Conheça o GiGA Router  Fique a saber tudo sobre o GiGA Router, que marca a aposta continua da NOS na evolução tecnológica. Em três versões diferentes, permite velocidades até 1Gb/s, tem Dual band norma AC, Wave2 e MIMO 4x4.   O GiGA Router apresenta como funcionalidades avançadas: Wi-Fi mais rápido, as 4x4 antenas integradas no router permitem atingir velocidades ultrarrápidas Velocidade máxima, velocidade até 1Gbps de download Airtime fairness, garante o mesmo tempo de transmissão a todos os equipamentos ligados por Wi-Fi ao Router, permitindo uma maior performance Beamforming, concentra e dirige o sinal Wi-Fi para onde estão ligados os equipamentos, melhorando o alcance e a velocidade Melhor performance e mais equipamentos ligados, até 50 equipamentos ligados ao mesmo tempo sem perder performance Funcionalidades avançadas, com a App NOS Net é possível controlar a Internet do router em qualquer lugar Gaming e Streaming, ideal para os mais exigentes que valorizam Gaming, streaming de vídeos HD e partilha de conteúdos de grandes dimensões   Para os nossos utilizadores mais técnicos, partilhamos também as principais características do novo GiGa Router: Wi-Fi Dual band 2,4/5GHz, 2,4GHz 802.11 b/g/n com MIMO 3x3 e 5GHz 802.11 a/n/ac Wave2 MU-MIMO 4x4 4 portas LAN (Ethernet) para acesso à internet por cabo 2 entradas telefónicas Porta USB 3.0 Botão para emparelhar Wi-Fi Botão de reset Indicador luminoso de estado   Saiba aqui mais sobre o GiGA Router. Conheça ainda em detalhe os três equipamentos aqui.  Já utilizou o GiGA Router? Partilhe connosco a sua experiência! :)  ',
#        'Conheça o GiGA Router  Fique a saber tudo sobre o GiGA Router, que marca a aposta continua da NOS na evolução tecnológica. Em três versões diferentes, permite velocidades até 1Gb/s, tem Dual band norma AC, Wave2 e MIMO 4x4.   O GiGA Router apresenta como funcionalidades avançadas: Wi-Fi mais rápido, as 4x4 antenas integradas no router permitem atingir velocidades ultrarrápidas Velocidade máxima, velocidade até 1Gbps de download Airtime fairness, garante o mesmo tempo de transmissão a todos os equipamentos ligados por Wi-Fi ao Router, permitindo uma maior performance Beamforming, concentra e dirige o sinal Wi-Fi para onde estão ligados os equipamentos, melhorando o alcance e a velocidade Melhor performance e mais equipamentos ligados, até 50 equipamentos ligados ao mesmo tempo sem perder performance Funcionalidades avançadas, com a App NOS Net é possível controlar a Internet do router em qualquer lugar Gaming e Streaming, ideal para os mais exigentes que valorizam Gaming, streaming de vídeos HD e partilha de conteúdos de grandes dimensões   Para os nossos utilizadores mais técnicos, partilhamos também as principais características do novo GiGa Router: Wi-Fi Dual band 2,4/5GHz, 2,4GHz 802.11 b/g/n com MIMO 3x3 e 5GHz 802.11 a/n/ac Wave2 MU-MIMO 4x4 4 portas LAN (Ethernet) para acesso à internet por cabo 2 entradas telefónicas Porta USB 3.0 Botão para emparelhar Wi-Fi Botão de reset Indicador luminoso de estado   Saiba aqui mais sobre o GiGA Router. Conheça ainda em detalhe os três equipamentos aqui.  Já utilizou o GiGA Router? Partilhe connosco a sua experiência! :)  ',
#        'Conheça o GiGA Router  Fique a saber tudo sobre o GiGA Router, que marca a aposta continua da NOS na evolução tecnológica. Em três versões diferentes, permite velocidades até 1Gb/s, tem Dual band norma AC, Wave2 e MIMO 4x4.   O GiGA Router apresenta como funcionalidades avançadas: Wi-Fi mais rápido, as 4x4 antenas integradas no router permitem atingir velocidades ultrarrápidas Velocidade máxima, velocidade até 1Gbps de download Airtime fairness, garante o mesmo tempo de transmissão a todos os equipamentos ligados por Wi-Fi ao Router, permitindo uma maior performance Beamforming, concentra e dirige o sinal Wi-Fi para onde estão ligados os equipamentos, melhorando o alcance e a velocidade Melhor performance e mais equipamentos ligados, até 50 equipamentos ligados ao mesmo tempo sem perder performance Funcionalidades avançadas, com a App NOS Net é possível controlar a Internet do router em qualquer lugar Gaming e Streaming, ideal para os mais exigentes que valorizam Gaming, streaming de vídeos HD e partilha de conteúdos de grandes dimensões   Para os nossos utilizadores mais técnicos, partilhamos também as principais características do novo GiGa Router: Wi-Fi Dual band 2,4/5GHz, 2,4GHz 802.11 b/g/n com MIMO 3x3 e 5GHz 802.11 a/n/ac Wave2 MU-MIMO 4x4 4 portas LAN (Ethernet) para acesso à internet por cabo 2 entradas telefónicas Porta USB 3.0 Botão para emparelhar Wi-Fi Botão de reset Indicador luminoso de estado   Saiba aqui mais sobre o GiGA Router. Conheça ainda em detalhe os três equipamentos aqui.  Já utilizou o GiGA Router? Partilhe connosco a sua experiência! :)  ',
#        'Conheça o GiGA Router  Fique a saber tudo sobre o GiGA Router, que marca a aposta continua da NOS na evolução tecnológica. Em três versões diferentes, permite velocidades até 1Gb/s, tem Dual band norma AC, Wave2 e MIMO 4x4.   O GiGA Router apresenta como funcionalidades avançadas: Wi-Fi mais rápido, as 4x4 antenas integradas no router permitem atingir velocidades ultrarrápidas Velocidade máxima, velocidade até 1Gbps de download Airtime fairness, garante o mesmo tempo de transmissão a todos os equipamentos ligados por Wi-Fi ao Router, permitindo uma maior performance Beamforming, concentra e dirige o sinal Wi-Fi para onde estão ligados os equipamentos, melhorando o alcance e a velocidade Melhor performance e mais equipamentos ligados, até 50 equipamentos ligados ao mesmo tempo sem perder performance Funcionalidades avançadas, com a App NOS Net é possível controlar a Internet do router em qualquer lugar Gaming e Streaming, ideal para os mais exigentes que valorizam Gaming, streaming de vídeos HD e partilha de conteúdos de grandes dimensões   Para os nossos utilizadores mais técnicos, partilhamos também as principais características do novo GiGa Router: Wi-Fi Dual band 2,4/5GHz, 2,4GHz 802.11 b/g/n com MIMO 3x3 e 5GHz 802.11 a/n/ac Wave2 MU-MIMO 4x4 4 portas LAN (Ethernet) para acesso à internet por cabo 2 entradas telefónicas Porta USB 3.0 Botão para emparelhar Wi-Fi Botão de reset Indicador luminoso de estado   Saiba aqui mais sobre o GiGA Router. Conheça ainda em detalhe os três equipamentos aqui.  Já utilizou o GiGA Router? Partilhe connosco a sua experiência! :)  ',
#        'Conheça o GiGA Router  Fique a saber tudo sobre o GiGA Router, que marca a aposta continua da NOS na evolução tecnológica. Em três versões diferentes, permite velocidades até 1Gb/s, tem Dual band norma AC, Wave2 e MIMO 4x4.   O GiGA Router apresenta como funcionalidades avançadas: Wi-Fi mais rápido, as 4x4 antenas integradas no router permitem atingir velocidades ultrarrápidas Velocidade máxima, velocidade até 1Gbps de download Airtime fairness, garante o mesmo tempo de transmissão a todos os equipamentos ligados por Wi-Fi ao Router, permitindo uma maior performance Beamforming, concentra e dirige o sinal Wi-Fi para onde estão ligados os equipamentos, melhorando o alcance e a velocidade Melhor performance e mais equipamentos ligados, até 50 equipamentos ligados ao mesmo tempo sem perder performance Funcionalidades avançadas, com a App NOS Net é possível controlar a Internet do router em qualquer lugar Gaming e Streaming, ideal para os mais exigentes que valorizam Gaming, streaming de vídeos HD e partilha de conteúdos de grandes dimensões   Para os nossos utilizadores mais técnicos, partilhamos também as principais características do novo GiGa Router: Wi-Fi Dual band 2,4/5GHz, 2,4GHz 802.11 b/g/n com MIMO 3x3 e 5GHz 802.11 a/n/ac Wave2 MU-MIMO 4x4 4 portas LAN (Ethernet) para acesso à internet por cabo 2 entradas telefónicas Porta USB 3.0 Botão para emparelhar Wi-Fi Botão de reset Indicador luminoso de estado   Saiba aqui mais sobre o GiGA Router. Conheça ainda em detalhe os três equipamentos aqui.  Já utilizou o GiGA Router? Partilhe connosco a sua experiência! :)  ',
#        'Conheça o GiGA Router  Fique a saber tudo sobre o GiGA Router, que marca a aposta continua da NOS na evolução tecnológica. Em três versões diferentes, permite velocidades até 1Gb/s, tem Dual band norma AC, Wave2 e MIMO 4x4.   O GiGA Router apresenta como funcionalidades avançadas: Wi-Fi mais rápido, as 4x4 antenas integradas no router permitem atingir velocidades ultrarrápidas Velocidade máxima, velocidade até 1Gbps de download Airtime fairness, garante o mesmo tempo de transmissão a todos os equipamentos ligados por Wi-Fi ao Router, permitindo uma maior performance Beamforming, concentra e dirige o sinal Wi-Fi para onde estão ligados os equipamentos, melhorando o alcance e a velocidade Melhor performance e mais equipamentos ligados, até 50 equipamentos ligados ao mesmo tempo sem perder performance Funcionalidades avançadas, com a App NOS Net é possível controlar a Internet do router em qualquer lugar Gaming e Streaming, ideal para os mais exigentes que valorizam Gaming, streaming de vídeos HD e partilha de conteúdos de grandes dimensões   Para os nossos utilizadores mais técnicos, partilhamos também as principais características do novo GiGa Router: Wi-Fi Dual band 2,4/5GHz, 2,4GHz 802.11 b/g/n com MIMO 3x3 e 5GHz 802.11 a/n/ac Wave2 MU-MIMO 4x4 4 portas LAN (Ethernet) para acesso à internet por cabo 2 entradas telefónicas Porta USB 3.0 Botão para emparelhar Wi-Fi Botão de reset Indicador luminoso de estado   Saiba aqui mais sobre o GiGA Router. Conheça ainda em detalhe os três equipamentos aqui.  Já utilizou o GiGA Router? Partilhe connosco a sua experiência! :)  ',
#        'Conheça o GiGA Router  Fique a saber tudo sobre o GiGA Router, que marca a aposta continua da NOS na evolução tecnológica. Em três versões diferentes, permite velocidades até 1Gb/s, tem Dual band norma AC, Wave2 e MIMO 4x4.   O GiGA Router apresenta como funcionalidades avançadas: Wi-Fi mais rápido, as 4x4 antenas integradas no router permitem atingir velocidades ultrarrápidas Velocidade máxima, velocidade até 1Gbps de download Airtime fairness, garante o mesmo tempo de transmissão a todos os equipamentos ligados por Wi-Fi ao Router, permitindo uma maior performance Beamforming, concentra e dirige o sinal Wi-Fi para onde estão ligados os equipamentos, melhorando o alcance e a velocidade Melhor performance e mais equipamentos ligados, até 50 equipamentos ligados ao mesmo tempo sem perder performance Funcionalidades avançadas, com a App NOS Net é possível controlar a Internet do router em qualquer lugar Gaming e Streaming, ideal para os mais exigentes que valorizam Gaming, streaming de vídeos HD e partilha de conteúdos de grandes dimensões   Para os nossos utilizadores mais técnicos, partilhamos também as principais características do novo GiGa Router: Wi-Fi Dual band 2,4/5GHz, 2,4GHz 802.11 b/g/n com MIMO 3x3 e 5GHz 802.11 a/n/ac Wave2 MU-MIMO 4x4 4 portas LAN (Ethernet) para acesso à internet por cabo 2 entradas telefónicas Porta USB 3.0 Botão para emparelhar Wi-Fi Botão de reset Indicador luminoso de estado   Saiba aqui mais sobre o GiGA Router. Conheça ainda em detalhe os três equipamentos aqui.  Já utilizou o GiGA Router? Partilhe connosco a sua experiência! :)  ',
#        'Conheça o GiGA Router  Fique a saber tudo sobre o GiGA Router, que marca a aposta continua da NOS na evolução tecnológica. Em três versões diferentes, permite velocidades até 1Gb/s, tem Dual band norma AC, Wave2 e MIMO 4x4.   O GiGA Router apresenta como funcionalidades avançadas: Wi-Fi mais rápido, as 4x4 antenas integradas no router permitem atingir velocidades ultrarrápidas Velocidade máxima, velocidade até 1Gbps de download Airtime fairness, garante o mesmo tempo de transmissão a todos os equipamentos ligados por Wi-Fi ao Router, permitindo uma maior performance Beamforming, concentra e dirige o sinal Wi-Fi para onde estão ligados os equipamentos, melhorando o alcance e a velocidade Melhor performance e mais equipamentos ligados, até 50 equipamentos ligados ao mesmo tempo sem perder performance Funcionalidades avançadas, com a App NOS Net é possível controlar a Internet do router em qualquer lugar Gaming e Streaming, ideal para os mais exigentes que valorizam Gaming, streaming de vídeos HD e partilha de conteúdos de grandes dimensões   Para os nossos utilizadores mais técnicos, partilhamos também as principais características do novo GiGa Router: Wi-Fi Dual band 2,4/5GHz, 2,4GHz 802.11 b/g/n com MIMO 3x3 e 5GHz 802.11 a/n/ac Wave2 MU-MIMO 4x4 4 portas LAN (Ethernet) para acesso à internet por cabo 2 entradas telefónicas Porta USB 3.0 Botão para emparelhar Wi-Fi Botão de reset Indicador luminoso de estado   Saiba aqui mais sobre o GiGA Router. Conheça ainda em detalhe os três equipamentos aqui.  Já utilizou o GiGA Router? Partilhe connosco a sua experiência! :)  ',
#        'Conheça o GiGA Router  Fique a saber tudo sobre o GiGA Router, que marca a aposta continua da NOS na evolução tecnológica. Em três versões diferentes, permite velocidades até 1Gb/s, tem Dual band norma AC, Wave2 e MIMO 4x4.   O GiGA Router apresenta como funcionalidades avançadas: Wi-Fi mais rápido, as 4x4 antenas integradas no router permitem atingir velocidades ultrarrápidas Velocidade máxima, velocidade até 1Gbps de download Airtime fairness, garante o mesmo tempo de transmissão a todos os equipamentos ligados por Wi-Fi ao Router, permitindo uma maior performance Beamforming, concentra e dirige o sinal Wi-Fi para onde estão ligados os equipamentos, melhorando o alcance e a velocidade Melhor performance e mais equipamentos ligados, até 50 equipamentos ligados ao mesmo tempo sem perder performance Funcionalidades avançadas, com a App NOS Net é possível controlar a Internet do router em qualquer lugar Gaming e Streaming, ideal para os mais exigentes que valorizam Gaming, streaming de vídeos HD e partilha de conteúdos de grandes dimensões   Para os nossos utilizadores mais técnicos, partilhamos também as principais características do novo GiGa Router: Wi-Fi Dual band 2,4/5GHz, 2,4GHz 802.11 b/g/n com MIMO 3x3 e 5GHz 802.11 a/n/ac Wave2 MU-MIMO 4x4 4 portas LAN (Ethernet) para acesso à internet por cabo 2 entradas telefónicas Porta USB 3.0 Botão para emparelhar Wi-Fi Botão de reset Indicador luminoso de estado   Saiba aqui mais sobre o GiGA Router. Conheça ainda em detalhe os três equipamentos aqui.  Já utilizou o GiGA Router? Partilhe connosco a sua experiência! :)  ',
#        'Conheça o GiGA Router  Fique a saber tudo sobre o GiGA Router, que marca a aposta continua da NOS na evolução tecnológica. Em três versões diferentes, permite velocidades até 1Gb/s, tem Dual band norma AC, Wave2 e MIMO 4x4.   O GiGA Router apresenta como funcionalidades avançadas: Wi-Fi mais rápido, as 4x4 antenas integradas no router permitem atingir velocidades ultrarrápidas Velocidade máxima, velocidade até 1Gbps de download Airtime fairness, garante o mesmo tempo de transmissão a todos os equipamentos ligados por Wi-Fi ao Router, permitindo uma maior performance Beamforming, concentra e dirige o sinal Wi-Fi para onde estão ligados os equipamentos, melhorando o alcance e a velocidade Melhor performance e mais equipamentos ligados, até 50 equipamentos ligados ao mesmo tempo sem perder performance Funcionalidades avançadas, com a App NOS Net é possível controlar a Internet do router em qualquer lugar Gaming e Streaming, ideal para os mais exigentes que valorizam Gaming, streaming de vídeos HD e partilha de conteúdos de grandes dimensões   Para os nossos utilizadores mais técnicos, partilhamos também as principais características do novo GiGa Router: Wi-Fi Dual band 2,4/5GHz, 2,4GHz 802.11 b/g/n com MIMO 3x3 e 5GHz 802.11 a/n/ac Wave2 MU-MIMO 4x4 4 portas LAN (Ethernet) para acesso à internet por cabo 2 entradas telefónicas Porta USB 3.0 Botão para emparelhar Wi-Fi Botão de reset Indicador luminoso de estado   Saiba aqui mais sobre o GiGA Router. Conheça ainda em detalhe os três equipamentos aqui.  Já utilizou o GiGA Router? Partilhe connosco a sua experiência! :)  ',
#        'Conheça o GiGA Router  Fique a saber tudo sobre o GiGA Router, que marca a aposta continua da NOS na evolução tecnológica. Em três versões diferentes, permite velocidades até 1Gb/s, tem Dual band norma AC, Wave2 e MIMO 4x4.   O GiGA Router apresenta como funcionalidades avançadas: Wi-Fi mais rápido, as 4x4 antenas integradas no router permitem atingir velocidades ultrarrápidas Velocidade máxima, velocidade até 1Gbps de download Airtime fairness, garante o mesmo tempo de transmissão a todos os equipamentos ligados por Wi-Fi ao Router, permitindo uma maior performance Beamforming, concentra e dirige o sinal Wi-Fi para onde estão ligados os equipamentos, melhorando o alcance e a velocidade Melhor performance e mais equipamentos ligados, até 50 equipamentos ligados ao mesmo tempo sem perder performance Funcionalidades avançadas, com a App NOS Net é possível controlar a Internet do router em qualquer lugar Gaming e Streaming, ideal para os mais exigentes que valorizam Gaming, streaming de vídeos HD e partilha de conteúdos de grandes dimensões   Para os nossos utilizadores mais técnicos, partilhamos também as principais características do novo GiGa Router: Wi-Fi Dual band 2,4/5GHz, 2,4GHz 802.11 b/g/n com MIMO 3x3 e 5GHz 802.11 a/n/ac Wave2 MU-MIMO 4x4 4 portas LAN (Ethernet) para acesso à internet por cabo 2 entradas telefónicas Porta USB 3.0 Botão para emparelhar Wi-Fi Botão de reset Indicador luminoso de estado   Saiba aqui mais sobre o GiGA Router. Conheça ainda em detalhe os três equipamentos aqui.  Já utilizou o GiGA Router? Partilhe connosco a sua experiência! :)  ',
#        'Conheça o GiGA Router  Fique a saber tudo sobre o GiGA Router, que marca a aposta continua da NOS na evolução tecnológica. Em três versões diferentes, permite velocidades até 1Gb/s, tem Dual band norma AC, Wave2 e MIMO 4x4.   O GiGA Router apresenta como funcionalidades avançadas: Wi-Fi mais rápido, as 4x4 antenas integradas no router permitem atingir velocidades ultrarrápidas Velocidade máxima, velocidade até 1Gbps de download Airtime fairness, garante o mesmo tempo de transmissão a todos os equipamentos ligados por Wi-Fi ao Router, permitindo uma maior performance Beamforming, concentra e dirige o sinal Wi-Fi para onde estão ligados os equipamentos, melhorando o alcance e a velocidade Melhor performance e mais equipamentos ligados, até 50 equipamentos ligados ao mesmo tempo sem perder performance Funcionalidades avançadas, com a App NOS Net é possível controlar a Internet do router em qualquer lugar Gaming e Streaming, ideal para os mais exigentes que valorizam Gaming, streaming de vídeos HD e partilha de conteúdos de grandes dimensões   Para os nossos utilizadores mais técnicos, partilhamos também as principais características do novo GiGa Router: Wi-Fi Dual band 2,4/5GHz, 2,4GHz 802.11 b/g/n com MIMO 3x3 e 5GHz 802.11 a/n/ac Wave2 MU-MIMO 4x4 4 portas LAN (Ethernet) para acesso à internet por cabo 2 entradas telefónicas Porta USB 3.0 Botão para emparelhar Wi-Fi Botão de reset Indicador luminoso de estado   Saiba aqui mais sobre o GiGA Router. Conheça ainda em detalhe os três equipamentos aqui.  Já utilizou o GiGA Router? Partilhe connosco a sua experiência! :)  ',
#        'Conheça o GiGA Router  Fique a saber tudo sobre o GiGA Router, que marca a aposta continua da NOS na evolução tecnológica. Em três versões diferentes, permite velocidades até 1Gb/s, tem Dual band norma AC, Wave2 e MIMO 4x4.   O GiGA Router apresenta como funcionalidades avançadas: Wi-Fi mais rápido, as 4x4 antenas integradas no router permitem atingir velocidades ultrarrápidas Velocidade máxima, velocidade até 1Gbps de download Airtime fairness, garante o mesmo tempo de transmissão a todos os equipamentos ligados por Wi-Fi ao Router, permitindo uma maior performance Beamforming, concentra e dirige o sinal Wi-Fi para onde estão ligados os equipamentos, melhorando o alcance e a velocidade Melhor performance e mais equipamentos ligados, até 50 equipamentos ligados ao mesmo tempo sem perder performance Funcionalidades avançadas, com a App NOS Net é possível controlar a Internet do router em qualquer lugar Gaming e Streaming, ideal para os mais exigentes que valorizam Gaming, streaming de vídeos HD e partilha de conteúdos de grandes dimensões   Para os nossos utilizadores mais técnicos, partilhamos também as principais características do novo GiGa Router: Wi-Fi Dual band 2,4/5GHz, 2,4GHz 802.11 b/g/n com MIMO 3x3 e 5GHz 802.11 a/n/ac Wave2 MU-MIMO 4x4 4 portas LAN (Ethernet) para acesso à internet por cabo 2 entradas telefónicas Porta USB 3.0 Botão para emparelhar Wi-Fi Botão de reset Indicador luminoso de estado   Saiba aqui mais sobre o GiGA Router. Conheça ainda em detalhe os três equipamentos aqui.  Já utilizou o GiGA Router? Partilhe connosco a sua experiência! :)  ',
#        'Conheça o GiGA Router  Fique a saber tudo sobre o GiGA Router, que marca a aposta continua da NOS na evolução tecnológica. Em três versões diferentes, permite velocidades até 1Gb/s, tem Dual band norma AC, Wave2 e MIMO 4x4.   O GiGA Router apresenta como funcionalidades avançadas: Wi-Fi mais rápido, as 4x4 antenas integradas no router permitem atingir velocidades ultrarrápidas Velocidade máxima, velocidade até 1Gbps de download Airtime fairness, garante o mesmo tempo de transmissão a todos os equipamentos ligados por Wi-Fi ao Router, permitindo uma maior performance Beamforming, concentra e dirige o sinal Wi-Fi para onde estão ligados os equipamentos, melhorando o alcance e a velocidade Melhor performance e mais equipamentos ligados, até 50 equipamentos ligados ao mesmo tempo sem perder performance Funcionalidades avançadas, com a App NOS Net é possível controlar a Internet do router em qualquer lugar Gaming e Streaming, ideal para os mais exigentes que valorizam Gaming, streaming de vídeos HD e partilha de conteúdos de grandes dimensões   Para os nossos utilizadores mais técnicos, partilhamos também as principais características do novo GiGa Router: Wi-Fi Dual band 2,4/5GHz, 2,4GHz 802.11 b/g/n com MIMO 3x3 e 5GHz 802.11 a/n/ac Wave2 MU-MIMO 4x4 4 portas LAN (Ethernet) para acesso à internet por cabo 2 entradas telefónicas Porta USB 3.0 Botão para emparelhar Wi-Fi Botão de reset Indicador luminoso de estado   Saiba aqui mais sobre o GiGA Router. Conheça ainda em detalhe os três equipamentos aqui.  Já utilizou o GiGA Router? Partilhe connosco a sua experiência! :)  ',
#        'Conheça o GiGA Router  Fique a saber tudo sobre o GiGA Router, que marca a aposta continua da NOS na evolução tecnológica. Em três versões diferentes, permite velocidades até 1Gb/s, tem Dual band norma AC, Wave2 e MIMO 4x4.   O GiGA Router apresenta como funcionalidades avançadas: Wi-Fi mais rápido, as 4x4 antenas integradas no router permitem atingir velocidades ultrarrápidas Velocidade máxima, velocidade até 1Gbps de download Airtime fairness, garante o mesmo tempo de transmissão a todos os equipamentos ligados por Wi-Fi ao Router, permitindo uma maior performance Beamforming, concentra e dirige o sinal Wi-Fi para onde estão ligados os equipamentos, melhorando o alcance e a velocidade Melhor performance e mais equipamentos ligados, até 50 equipamentos ligados ao mesmo tempo sem perder performance Funcionalidades avançadas, com a App NOS Net é possível controlar a Internet do router em qualquer lugar Gaming e Streaming, ideal para os mais exigentes que valorizam Gaming, streaming de vídeos HD e partilha de conteúdos de grandes dimensões   Para os nossos utilizadores mais técnicos, partilhamos também as principais características do novo GiGa Router: Wi-Fi Dual band 2,4/5GHz, 2,4GHz 802.11 b/g/n com MIMO 3x3 e 5GHz 802.11 a/n/ac Wave2 MU-MIMO 4x4 4 portas LAN (Ethernet) para acesso à internet por cabo 2 entradas telefónicas Porta USB 3.0 Botão para emparelhar Wi-Fi Botão de reset Indicador luminoso de estado   Saiba aqui mais sobre o GiGA Router. Conheça ainda em detalhe os três equipamentos aqui.  Já utilizou o GiGA Router? Partilhe connosco a sua experiência! :)  ',
#        'Conheça o GiGA Router  Fique a saber tudo sobre o GiGA Router, que marca a aposta continua da NOS na evolução tecnológica. Em três versões diferentes, permite velocidades até 1Gb/s, tem Dual band norma AC, Wave2 e MIMO 4x4.   O GiGA Router apresenta como funcionalidades avançadas: Wi-Fi mais rápido, as 4x4 antenas integradas no router permitem atingir velocidades ultrarrápidas Velocidade máxima, velocidade até 1Gbps de download Airtime fairness, garante o mesmo tempo de transmissão a todos os equipamentos ligados por Wi-Fi ao Router, permitindo uma maior performance Beamforming, concentra e dirige o sinal Wi-Fi para onde estão ligados os equipamentos, melhorando o alcance e a velocidade Melhor performance e mais equipamentos ligados, até 50 equipamentos ligados ao mesmo tempo sem perder performance Funcionalidades avançadas, com a App NOS Net é possível controlar a Internet do router em qualquer lugar Gaming e Streaming, ideal para os mais exigentes que valorizam Gaming, streaming de vídeos HD e partilha de conteúdos de grandes dimensões   Para os nossos utilizadores mais técnicos, partilhamos também as principais características do novo GiGa Router: Wi-Fi Dual band 2,4/5GHz, 2,4GHz 802.11 b/g/n com MIMO 3x3 e 5GHz 802.11 a/n/ac Wave2 MU-MIMO 4x4 4 portas LAN (Ethernet) para acesso à internet por cabo 2 entradas telefónicas Porta USB 3.0 Botão para emparelhar Wi-Fi Botão de reset Indicador luminoso de estado   Saiba aqui mais sobre o GiGA Router. Conheça ainda em detalhe os três equipamentos aqui.  Já utilizou o GiGA Router? Partilhe connosco a sua experiência! :)  ',
#        'Conheça o GiGA Router  Fique a saber tudo sobre o GiGA Router, que marca a aposta continua da NOS na evolução tecnológica. Em três versões diferentes, permite velocidades até 1Gb/s, tem Dual band norma AC, Wave2 e MIMO 4x4.   O GiGA Router apresenta como funcionalidades avançadas: Wi-Fi mais rápido, as 4x4 antenas integradas no router permitem atingir velocidades ultrarrápidas Velocidade máxima, velocidade até 1Gbps de download Airtime fairness, garante o mesmo tempo de transmissão a todos os equipamentos ligados por Wi-Fi ao Router, permitindo uma maior performance Beamforming, concentra e dirige o sinal Wi-Fi para onde estão ligados os equipamentos, melhorando o alcance e a velocidade Melhor performance e mais equipamentos ligados, até 50 equipamentos ligados ao mesmo tempo sem perder performance Funcionalidades avançadas, com a App NOS Net é possível controlar a Internet do router em qualquer lugar Gaming e Streaming, ideal para os mais exigentes que valorizam Gaming, streaming de vídeos HD e partilha de conteúdos de grandes dimensões   Para os nossos utilizadores mais técnicos, partilhamos também as principais características do novo GiGa Router: Wi-Fi Dual band 2,4/5GHz, 2,4GHz 802.11 b/g/n com MIMO 3x3 e 5GHz 802.11 a/n/ac Wave2 MU-MIMO 4x4 4 portas LAN (Ethernet) para acesso à internet por cabo 2 entradas telefónicas Porta USB 3.0 Botão para emparelhar Wi-Fi Botão de reset Indicador luminoso de estado   Saiba aqui mais sobre o GiGA Router. Conheça ainda em detalhe os três equipamentos aqui.  Já utilizou o GiGA Router? Partilhe connosco a sua experiência! :)  ',
#        'Conheça o GiGA Router  Fique a saber tudo sobre o GiGA Router, que marca a aposta continua da NOS na evolução tecnológica. Em três versões diferentes, permite velocidades até 1Gb/s, tem Dual band norma AC, Wave2 e MIMO 4x4.   O GiGA Router apresenta como funcionalidades avançadas: Wi-Fi mais rápido, as 4x4 antenas integradas no router permitem atingir velocidades ultrarrápidas Velocidade máxima, velocidade até 1Gbps de download Airtime fairness, garante o mesmo tempo de transmissão a todos os equipamentos ligados por Wi-Fi ao Router, permitindo uma maior performance Beamforming, concentra e dirige o sinal Wi-Fi para onde estão ligados os equipamentos, melhorando o alcance e a velocidade Melhor performance e mais equipamentos ligados, até 50 equipamentos ligados ao mesmo tempo sem perder performance Funcionalidades avançadas, com a App NOS Net é possível controlar a Internet do router em qualquer lugar Gaming e Streaming, ideal para os mais exigentes que valorizam Gaming, streaming de vídeos HD e partilha de conteúdos de grandes dimensões   Para os nossos utilizadores mais técnicos, partilhamos também as principais características do novo GiGa Router: Wi-Fi Dual band 2,4/5GHz, 2,4GHz 802.11 b/g/n com MIMO 3x3 e 5GHz 802.11 a/n/ac Wave2 MU-MIMO 4x4 4 portas LAN (Ethernet) para acesso à internet por cabo 2 entradas telefónicas Porta USB 3.0 Botão para emparelhar Wi-Fi Botão de reset Indicador luminoso de estado   Saiba aqui mais sobre o GiGA Router. Conheça ainda em detalhe os três equipamentos aqui.  Já utilizou o GiGA Router? Partilhe connosco a sua experiência! :)  ',
#        'Conheça o GiGA Router  Fique a saber tudo sobre o GiGA Router, que marca a aposta continua da NOS na evolução tecnológica. Em três versões diferentes, permite velocidades até 1Gb/s, tem Dual band norma AC, Wave2 e MIMO 4x4.   O GiGA Router apresenta como funcionalidades avançadas: Wi-Fi mais rápido, as 4x4 antenas integradas no router permitem atingir velocidades ultrarrápidas Velocidade máxima, velocidade até 1Gbps de download Airtime fairness, garante o mesmo tempo de transmissão a todos os equipamentos ligados por Wi-Fi ao Router, permitindo uma maior performance Beamforming, concentra e dirige o sinal Wi-Fi para onde estão ligados os equipamentos, melhorando o alcance e a velocidade Melhor performance e mais equipamentos ligados, até 50 equipamentos ligados ao mesmo tempo sem perder performance Funcionalidades avançadas, com a App NOS Net é possível controlar a Internet do router em qualquer lugar Gaming e Streaming, ideal para os mais exigentes que valorizam Gaming, streaming de vídeos HD e partilha de conteúdos de grandes dimensões   Para os nossos utilizadores mais técnicos, partilhamos também as principais características do novo GiGa Router: Wi-Fi Dual band 2,4/5GHz, 2,4GHz 802.11 b/g/n com MIMO 3x3 e 5GHz 802.11 a/n/ac Wave2 MU-MIMO 4x4 4 portas LAN (Ethernet) para acesso à internet por cabo 2 entradas telefónicas Porta USB 3.0 Botão para emparelhar Wi-Fi Botão de reset Indicador luminoso de estado   Saiba aqui mais sobre o GiGA Router. Conheça ainda em detalhe os três equipamentos aqui.  Já utilizou o GiGA Router? Partilhe connosco a sua experiência! :)  ',
#        'Conheça o GiGA Router  Fique a saber tudo sobre o GiGA Router, que marca a aposta continua da NOS na evolução tecnológica. Em três versões diferentes, permite velocidades até 1Gb/s, tem Dual band norma AC, Wave2 e MIMO 4x4.   O GiGA Router apresenta como funcionalidades avançadas: Wi-Fi mais rápido, as 4x4 antenas integradas no router permitem atingir velocidades ultrarrápidas Velocidade máxima, velocidade até 1Gbps de download Airtime fairness, garante o mesmo tempo de transmissão a todos os equipamentos ligados por Wi-Fi ao Router, permitindo uma maior performance Beamforming, concentra e dirige o sinal Wi-Fi para onde estão ligados os equipamentos, melhorando o alcance e a velocidade Melhor performance e mais equipamentos ligados, até 50 equipamentos ligados ao mesmo tempo sem perder performance Funcionalidades avançadas, com a App NOS Net é possível controlar a Internet do router em qualquer lugar Gaming e Streaming, ideal para os mais exigentes que valorizam Gaming, streaming de vídeos HD e partilha de conteúdos de grandes dimensões   Para os nossos utilizadores mais técnicos, partilhamos também as principais características do novo GiGa Router: Wi-Fi Dual band 2,4/5GHz, 2,4GHz 802.11 b/g/n com MIMO 3x3 e 5GHz 802.11 a/n/ac Wave2 MU-MIMO 4x4 4 portas LAN (Ethernet) para acesso à internet por cabo 2 entradas telefónicas Porta USB 3.0 Botão para emparelhar Wi-Fi Botão de reset Indicador luminoso de estado   Saiba aqui mais sobre o GiGA Router. Conheça ainda em detalhe os três equipamentos aqui.  Já utilizou o GiGA Router? Partilhe connosco a sua experiência! :)  ',
#        'Conheça o GiGA Router  Fique a saber tudo sobre o GiGA Router, que marca a aposta continua da NOS na evolução tecnológica. Em três versões diferentes, permite velocidades até 1Gb/s, tem Dual band norma AC, Wave2 e MIMO 4x4.   O GiGA Router apresenta como funcionalidades avançadas: Wi-Fi mais rápido, as 4x4 antenas integradas no router permitem atingir velocidades ultrarrápidas Velocidade máxima, velocidade até 1Gbps de download Airtime fairness, garante o mesmo tempo de transmissão a todos os equipamentos ligados por Wi-Fi ao Router, permitindo uma maior performance Beamforming, concentra e dirige o sinal Wi-Fi para onde estão ligados os equipamentos, melhorando o alcance e a velocidade Melhor performance e mais equipamentos ligados, até 50 equipamentos ligados ao mesmo tempo sem perder performance Funcionalidades avançadas, com a App NOS Net é possível controlar a Internet do router em qualquer lugar Gaming e Streaming, ideal para os mais exigentes que valorizam Gaming, streaming de vídeos HD e partilha de conteúdos de grandes dimensões   Para os nossos utilizadores mais técnicos, partilhamos também as principais características do novo GiGa Router: Wi-Fi Dual band 2,4/5GHz, 2,4GHz 802.11 b/g/n com MIMO 3x3 e 5GHz 802.11 a/n/ac Wave2 MU-MIMO 4x4 4 portas LAN (Ethernet) para acesso à internet por cabo 2 entradas telefónicas Porta USB 3.0 Botão para emparelhar Wi-Fi Botão de reset Indicador luminoso de estado   Saiba aqui mais sobre o GiGA Router. Conheça ainda em detalhe os três equipamentos aqui.  Já utilizou o GiGA Router? Partilhe connosco a sua experiência! :)  ',
#        'Conheça o GiGA Router  Fique a saber tudo sobre o GiGA Router, que marca a aposta continua da NOS na evolução tecnológica. Em três versões diferentes, permite velocidades até 1Gb/s, tem Dual band norma AC, Wave2 e MIMO 4x4.   O GiGA Router apresenta como funcionalidades avançadas: Wi-Fi mais rápido, as 4x4 antenas integradas no router permitem atingir velocidades ultrarrápidas Velocidade máxima, velocidade até 1Gbps de download Airtime fairness, garante o mesmo tempo de transmissão a todos os equipamentos ligados por Wi-Fi ao Router, permitindo uma maior performance Beamforming, concentra e dirige o sinal Wi-Fi para onde estão ligados os equipamentos, melhorando o alcance e a velocidade Melhor performance e mais equipamentos ligados, até 50 equipamentos ligados ao mesmo tempo sem perder performance Funcionalidades avançadas, com a App NOS Net é possível controlar a Internet do router em qualquer lugar Gaming e Streaming, ideal para os mais exigentes que valorizam Gaming, streaming de vídeos HD e partilha de conteúdos de grandes dimensões   Para os nossos utilizadores mais técnicos, partilhamos também as principais características do novo GiGa Router: Wi-Fi Dual band 2,4/5GHz, 2,4GHz 802.11 b/g/n com MIMO 3x3 e 5GHz 802.11 a/n/ac Wave2 MU-MIMO 4x4 4 portas LAN (Ethernet) para acesso à internet por cabo 2 entradas telefónicas Porta USB 3.0 Botão para emparelhar Wi-Fi Botão de reset Indicador luminoso de estado   Saiba aqui mais sobre o GiGA Router. Conheça ainda em detalhe os três equipamentos aqui.  Já utilizou o GiGA Router? Partilhe connosco a sua experiência! :)  ',
# ...
#        'Boa noite, Gostaria de saber quanto tempo demora a recepcionar o "código de validação". Este será enviado através de sms, email ou carta? É que não é especificado na área de cliente. icon Melhor resposta por Oscar7 Tenho ideia que demora 8 dias. Ver pergunta inicial',
#        'Há dois anos, porque o router tinha cobertura deficiente, solicitei a troca desse router por um Power Router 4.0. Paguei a instalação e, na minha boa fé, não esclareci muitos pormenores. Agora, dois anos passados, começaram a cobrar-me 5,039€ por mês. Parece que na NOS é assim. Ao fim de dois anos passa a pagar-se o aluguer do Router. Mas a culpa foi minha. Não me informaram na altura e não tive o cuidado de verificar cuidadosamente as condições do serviço. Contudo, a minha questão para a comunidade ou moderadores é a seguinte: Porquê é que pago 5,039€ quando no preçário que consta do site da NOS o aluguer do Power Router 4.0 é de apenas 1,99€? Agradeço os esclarecimentos que me possam prestar.',
#        'Há dois anos, porque o router tinha cobertura deficiente, solicitei a troca desse router por um Power Router 4.0. Paguei a instalação e, na minha boa fé, não esclareci muitos pormenores. Agora, dois anos passados, começaram a cobrar-me 5,039€ por mês. Parece que na NOS é assim. Ao fim de dois anos passa a pagar-se o aluguer do Router. Mas a culpa foi minha. Não me informaram na altura e não tive o cuidado de verificar cuidadosamente as condições do serviço. Contudo, a minha questão para a comunidade ou moderadores é a seguinte: Porquê é que pago 5,039€ quando no preçário que consta do site da NOS o aluguer do Power Router 4.0 é de apenas 1,99€? Agradeço os esclarecimentos que me possam prestar.',
#        'Há dois anos, porque o router tinha cobertura deficiente, solicitei a troca desse router por um Power Router 4.0. Paguei a instalação e, na minha boa fé, não esclareci muitos pormenores. Agora, dois anos passados, começaram a cobrar-me 5,039€ por mês. Parece que na NOS é assim. Ao fim de dois anos passa a pagar-se o aluguer do Router. Mas a culpa foi minha. Não me informaram na altura e não tive o cuidado de verificar cuidadosamente as condições do serviço. Contudo, a minha questão para a comunidade ou moderadores é a seguinte: Porquê é que pago 5,039€ quando no preçário que consta do site da NOS o aluguer do Power Router 4.0 é de apenas 1,99€? Agradeço os esclarecimentos que me possam prestar.',
#        'Há dois anos, porque o router tinha cobertura deficiente, solicitei a troca desse router por um Power Router 4.0. Paguei a instalação e, na minha boa fé, não esclareci muitos pormenores. Agora, dois anos passados, começaram a cobrar-me 5,039€ por mês. Parece que na NOS é assim. Ao fim de dois anos passa a pagar-se o aluguer do Router. Mas a culpa foi minha. Não me informaram na altura e não tive o cuidado de verificar cuidadosamente as condições do serviço. Contudo, a minha questão para a comunidade ou moderadores é a seguinte: Porquê é que pago 5,039€ quando no preçário que consta do site da NOS o aluguer do Power Router 4.0 é de apenas 1,99€? Agradeço os esclarecimentos que me possam prestar.',
#        'Há dois anos, porque o router tinha cobertura deficiente, solicitei a troca desse router por um Power Router 4.0. Paguei a instalação e, na minha boa fé, não esclareci muitos pormenores. Agora, dois anos passados, começaram a cobrar-me 5,039€ por mês. Parece que na NOS é assim. Ao fim de dois anos passa a pagar-se o aluguer do Router. Mas a culpa foi minha. Não me informaram na altura e não tive o cuidado de verificar cuidadosamente as condições do serviço. Contudo, a minha questão para a comunidade ou moderadores é a seguinte: Porquê é que pago 5,039€ quando no preçário que consta do site da NOS o aluguer do Power Router 4.0 é de apenas 1,99€? Agradeço os esclarecimentos que me possam prestar.',
#        'Há dois anos, porque o router tinha cobertura deficiente, solicitei a troca desse router por um Power Router 4.0. Paguei a instalação e, na minha boa fé, não esclareci muitos pormenores. Agora, dois anos passados, começaram a cobrar-me 5,039€ por mês. Parece que na NOS é assim. Ao fim de dois anos passa a pagar-se o aluguer do Router. Mas a culpa foi minha. Não me informaram na altura e não tive o cuidado de verificar cuidadosamente as condições do serviço. Contudo, a minha questão para a comunidade ou moderadores é a seguinte: Porquê é que pago 5,039€ quando no preçário que consta do site da NOS o aluguer do Power Router 4.0 é de apenas 1,99€? Agradeço os esclarecimentos que me possam prestar.',
#        'Há dois anos, porque o router tinha cobertura deficiente, solicitei a troca desse router por um Power Router 4.0. Paguei a instalação e, na minha boa fé, não esclareci muitos pormenores. Agora, dois anos passados, começaram a cobrar-me 5,039€ por mês. Parece que na NOS é assim. Ao fim de dois anos passa a pagar-se o aluguer do Router. Mas a culpa foi minha. Não me informaram na altura e não tive o cuidado de verificar cuidadosamente as condições do serviço. Contudo, a minha questão para a comunidade ou moderadores é a seguinte: Porquê é que pago 5,039€ quando no preçário que consta do site da NOS o aluguer do Power Router 4.0 é de apenas 1,99€? Agradeço os esclarecimentos que me possam prestar.',
#        'Há dois anos, porque o router tinha cobertura deficiente, solicitei a troca desse router por um Power Router 4.0. Paguei a instalação e, na minha boa fé, não esclareci muitos pormenores. Agora, dois anos passados, começaram a cobrar-me 5,039€ por mês. Parece que na NOS é assim. Ao fim de dois anos passa a pagar-se o aluguer do Router. Mas a culpa foi minha. Não me informaram na altura e não tive o cuidado de verificar cuidadosamente as condições do serviço. Contudo, a minha questão para a comunidade ou moderadores é a seguinte: Porquê é que pago 5,039€ quando no preçário que consta do site da NOS o aluguer do Power Router 4.0 é de apenas 1,99€? Agradeço os esclarecimentos que me possam prestar.',
#        'Há dois anos, porque o router tinha cobertura deficiente, solicitei a troca desse router por um Power Router 4.0. Paguei a instalação e, na minha boa fé, não esclareci muitos pormenores. Agora, dois anos passados, começaram a cobrar-me 5,039€ por mês. Parece que na NOS é assim. Ao fim de dois anos passa a pagar-se o aluguer do Router. Mas a culpa foi minha. Não me informaram na altura e não tive o cuidado de verificar cuidadosamente as condições do serviço. Contudo, a minha questão para a comunidade ou moderadores é a seguinte: Porquê é que pago 5,039€ quando no preçário que consta do site da NOS o aluguer do Power Router 4.0 é de apenas 1,99€? Agradeço os esclarecimentos que me possam prestar.',
#        'Há dois anos, porque o router tinha cobertura deficiente, solicitei a troca desse router por um Power Router 4.0. Paguei a instalação e, na minha boa fé, não esclareci muitos pormenores. Agora, dois anos passados, começaram a cobrar-me 5,039€ por mês. Parece que na NOS é assim. Ao fim de dois anos passa a pagar-se o aluguer do Router. Mas a culpa foi minha. Não me informaram na altura e não tive o cuidado de verificar cuidadosamente as condições do serviço. Contudo, a minha questão para a comunidade ou moderadores é a seguinte: Porquê é que pago 5,039€ quando no preçário que consta do site da NOS o aluguer do Power Router 4.0 é de apenas 1,99€? Agradeço os esclarecimentos que me possam prestar.',
#        'Há dois anos, porque o router tinha cobertura deficiente, solicitei a troca desse router por um Power Router 4.0. Paguei a instalação e, na minha boa fé, não esclareci muitos pormenores. Agora, dois anos passados, começaram a cobrar-me 5,039€ por mês. Parece que na NOS é assim. Ao fim de dois anos passa a pagar-se o aluguer do Router. Mas a culpa foi minha. Não me informaram na altura e não tive o cuidado de verificar cuidadosamente as condições do serviço. Contudo, a minha questão para a comunidade ou moderadores é a seguinte: Porquê é que pago 5,039€ quando no preçário que consta do site da NOS o aluguer do Power Router 4.0 é de apenas 1,99€? Agradeço os esclarecimentos que me possam prestar.',
#        'Há dois anos, porque o router tinha cobertura deficiente, solicitei a troca desse router por um Power Router 4.0. Paguei a instalação e, na minha boa fé, não esclareci muitos pormenores. Agora, dois anos passados, começaram a cobrar-me 5,039€ por mês. Parece que na NOS é assim. Ao fim de dois anos passa a pagar-se o aluguer do Router. Mas a culpa foi minha. Não me informaram na altura e não tive o cuidado de verificar cuidadosamente as condições do serviço. Contudo, a minha questão para a comunidade ou moderadores é a seguinte: Porquê é que pago 5,039€ quando no preçário que consta do site da NOS o aluguer do Power Router 4.0 é de apenas 1,99€? Agradeço os esclarecimentos que me possam prestar.',
#        'Há dois anos, porque o router tinha cobertura deficiente, solicitei a troca desse router por um Power Router 4.0. Paguei a instalação e, na minha boa fé, não esclareci muitos pormenores. Agora, dois anos passados, começaram a cobrar-me 5,039€ por mês. Parece que na NOS é assim. Ao fim de dois anos passa a pagar-se o aluguer do Router. Mas a culpa foi minha. Não me informaram na altura e não tive o cuidado de verificar cuidadosamente as condições do serviço. Contudo, a minha questão para a comunidade ou moderadores é a seguinte: Porquê é que pago 5,039€ quando no preçário que consta do site da NOS o aluguer do Power Router 4.0 é de apenas 1,99€? Agradeço os esclarecimentos que me possam prestar.',
#        'Há dois anos, porque o router tinha cobertura deficiente, solicitei a troca desse router por um Power Router 4.0. Paguei a instalação e, na minha boa fé, não esclareci muitos pormenores. Agora, dois anos passados, começaram a cobrar-me 5,039€ por mês. Parece que na NOS é assim. Ao fim de dois anos passa a pagar-se o aluguer do Router. Mas a culpa foi minha. Não me informaram na altura e não tive o cuidado de verificar cuidadosamente as condições do serviço. Contudo, a minha questão para a comunidade ou moderadores é a seguinte: Porquê é que pago 5,039€ quando no preçário que consta do site da NOS o aluguer do Power Router 4.0 é de apenas 1,99€? Agradeço os esclarecimentos que me possam prestar.',
#        'Há dois anos, porque o router tinha cobertura deficiente, solicitei a troca desse router por um Power Router 4.0. Paguei a instalação e, na minha boa fé, não esclareci muitos pormenores. Agora, dois anos passados, começaram a cobrar-me 5,039€ por mês. Parece que na NOS é assim. Ao fim de dois anos passa a pagar-se o aluguer do Router. Mas a culpa foi minha. Não me informaram na altura e não tive o cuidado de verificar cuidadosamente as condições do serviço. Contudo, a minha questão para a comunidade ou moderadores é a seguinte: Porquê é que pago 5,039€ quando no preçário que consta do site da NOS o aluguer do Power Router 4.0 é de apenas 1,99€? Agradeço os esclarecimentos que me possam prestar.',
#        'Há dois anos, porque o router tinha cobertura deficiente, solicitei a troca desse router por um Power Router 4.0. Paguei a instalação e, na minha boa fé, não esclareci muitos pormenores. Agora, dois anos passados, começaram a cobrar-me 5,039€ por mês. Parece que na NOS é assim. Ao fim de dois anos passa a pagar-se o aluguer do Router. Mas a culpa foi minha. Não me informaram na altura e não tive o cuidado de verificar cuidadosamente as condições do serviço. Contudo, a minha questão para a comunidade ou moderadores é a seguinte: Porquê é que pago 5,039€ quando no preçário que consta do site da NOS o aluguer do Power Router 4.0 é de apenas 1,99€? Agradeço os esclarecimentos que me possam prestar.',
#        'Há dois anos, porque o router tinha cobertura deficiente, solicitei a troca desse router por um Power Router 4.0. Paguei a instalação e, na minha boa fé, não esclareci muitos pormenores. Agora, dois anos passados, começaram a cobrar-me 5,039€ por mês. Parece que na NOS é assim. Ao fim de dois anos passa a pagar-se o aluguer do Router. Mas a culpa foi minha. Não me informaram na altura e não tive o cuidado de verificar cuidadosamente as condições do serviço. Contudo, a minha questão para a comunidade ou moderadores é a seguinte: Porquê é que pago 5,039€ quando no preçário que consta do site da NOS o aluguer do Power Router 4.0 é de apenas 1,99€? Agradeço os esclarecimentos que me possam prestar.',
#        'Há dois anos, porque o router tinha cobertura deficiente, solicitei a troca desse router por um Power Router 4.0. Paguei a instalação e, na minha boa fé, não esclareci muitos pormenores. Agora, dois anos passados, começaram a cobrar-me 5,039€ por mês. Parece que na NOS é assim. Ao fim de dois anos passa a pagar-se o aluguer do Router. Mas a culpa foi minha. Não me informaram na altura e não tive o cuidado de verificar cuidadosamente as condições do serviço. Contudo, a minha questão para a comunidade ou moderadores é a seguinte: Porquê é que pago 5,039€ quando no preçário que consta do site da NOS o aluguer do Power Router 4.0 é de apenas 1,99€? Agradeço os esclarecimentos que me possam prestar.',
#        'Tenho o pacote da nos(fibra) ha 15 dias e tirando 2 ou 3 vezes é que o serviço não se vai todo abaixo isso inclui também o telefone, mas como tb nao tenho dinheiro no telemóvel para ligar uma linha de apoio que devia ser gratuita gostaria de perguntar se alguém aqui pode ajudar sabem algum numero gratuito ou a causa de o serviço de estar ir abaixo muitas vezes.',
#        'Tenho o pacote da nos(fibra) ha 15 dias e tirando 2 ou 3 vezes é que o serviço não se vai todo abaixo isso inclui também o telefone, mas como tb nao tenho dinheiro no telemóvel para ligar uma linha de apoio que devia ser gratuita gostaria de perguntar se alguém aqui pode ajudar sabem algum numero gratuito ou a causa de o serviço de estar ir abaixo muitas vezes.',
#        'Tenho o pacote da nos(fibra) ha 15 dias e tirando 2 ou 3 vezes é que o serviço não se vai todo abaixo isso inclui também o telefone, mas como tb nao tenho dinheiro no telemóvel para ligar uma linha de apoio que devia ser gratuita gostaria de perguntar se alguém aqui pode ajudar sabem algum numero gratuito ou a causa de o serviço de estar ir abaixo muitas vezes.',
#        'Tenho o pacote da nos(fibra) ha 15 dias e tirando 2 ou 3 vezes é que o serviço não se vai todo abaixo isso inclui também o telefone, mas como tb nao tenho dinheiro no telemóvel para ligar uma linha de apoio que devia ser gratuita gostaria de perguntar se alguém aqui pode ajudar sabem algum numero gratuito ou a causa de o serviço de estar ir abaixo muitas vezes.',
#        'Tenho o pacote da nos(fibra) ha 15 dias e tirando 2 ou 3 vezes é que o serviço não se vai todo abaixo isso inclui também o telefone, mas como tb nao tenho dinheiro no telemóvel para ligar uma linha de apoio que devia ser gratuita gostaria de perguntar se alguém aqui pode ajudar sabem algum numero gratuito ou a causa de o serviço de estar ir abaixo muitas vezes.',
#        'Tenho o pacote da nos(fibra) ha 15 dias e tirando 2 ou 3 vezes é que o serviço não se vai todo abaixo isso inclui também o telefone, mas como tb nao tenho dinheiro no telemóvel para ligar uma linha de apoio que devia ser gratuita gostaria de perguntar se alguém aqui pode ajudar sabem algum numero gratuito ou a causa de o serviço de estar ir abaixo muitas vezes.',
#        'Tenho o pacote da nos(fibra) ha 15 dias e tirando 2 ou 3 vezes é que o serviço não se vai todo abaixo isso inclui também o telefone, mas como tb nao tenho dinheiro no telemóvel para ligar uma linha de apoio que devia ser gratuita gostaria de perguntar se alguém aqui pode ajudar sabem algum numero gratuito ou a causa de o serviço de estar ir abaixo muitas vezes.'],
#       dtype='<U2606')

# %%
post_data2 = {'Data_recolha':post_data['Tempo_recolha'],
              'Categoria':post_data['Categoria'],
              'Empresa':post_data['Empresa'],
              'n': post_data['n'],
              'URL_Post': post_data['URL_Post'],
              'Title_Post': post_data['Theme_Pub'],
              'User_Post': post_data['User_Pub'],
              'Class_User_Post': post_data['Class_User_Pub'],
              'Texto_Post' : post_data['Texto_Pub'],
              'Data_Post' : post_data['Data_Pub'] ,
              'Likes_Post':post_data['Likes_Pub'], 

              'Users' : post_data['User_Conv'],
              'Class_Users': post_data['Class_Conv'], 
              'Data_coments': post_data['Data_Conv'],
              'Coments': post_data['Textos_Conv'], 
              'Likes_Coments': post_data['Likes_Conv']
             }

post_data3 = pd.DataFrame.from_dict(post_data2, orient='index')
base = post_data3.transpose()
base2 = base[base['Texto_Post'].notna()]
base2
# Out:
#                   Data_recolha        Categoria Empresa   n  \
# 0   2021-03-25 16:44:49.203667  Telecomunicação     NOS   1
# 1   2021-03-25 16:44:49.203667  Telecomunicação     NOS   1
# 2   2021-03-25 16:44:49.203667  Telecomunicação     NOS   1
# 3   2021-03-25 16:44:49.203667  Telecomunicação     NOS   1
# 4   2021-03-25 16:44:49.203667  Telecomunicação     NOS   1
# ..                         ...              ...     ...  ..
# 265 2021-03-25 16:47:19.961270  Telecomunicação     NOS  25
# 266 2021-03-25 16:47:19.961270  Telecomunicação     NOS  25
# 267 2021-03-25 16:47:19.961270  Telecomunicação     NOS  25
# 268 2021-03-25 16:47:19.961270  Telecomunicação     NOS  25
# 269 2021-03-25 16:47:19.961270  Telecomunicação     NOS  25
#
#                                               URL_Post  \
# 0    https://forum.nos.pt/configurar-o-telefone-fix...
# 1    https://forum.nos.pt/configurar-o-telefone-fix...
# 2    https://forum.nos.pt/configurar-o-telefone-fix...
# 3    https://forum.nos.pt/configurar-o-telefone-fix...
# 4    https://forum.nos.pt/configurar-o-telefone-fix...
# ..                                                 ...
# 265  https://forum.nos.pt/ver-televisao-em-casa-5/c...
# 266  https://forum.nos.pt/ver-televisao-em-casa-5/c...
# 267  https://forum.nos.pt/ver-televisao-em-casa-5/c...
# 268  https://forum.nos.pt/ver-televisao-em-casa-5/c...
# 269  https://forum.nos.pt/ver-televisao-em-casa-5/c...
#
#                                   Title_Post       User_Post Class_User_Post  \
# 0                       Avaria telefone fixo  Elísia Tavares       Yottabyte
# 1                       Avaria telefone fixo  Elísia Tavares       Yottabyte
# 2                       Avaria telefone fixo  Elísia Tavares       Yottabyte
# 3                       Avaria telefone fixo  Elísia Tavares       Yottabyte
# 4                       Avaria telefone fixo  Elísia Tavares       Yottabyte
# ..                                       ...             ...             ...
# 265  como obter apoio por Telefone sem pagar  Diana Sobreira        Megabyte
# 266  como obter apoio por Telefone sem pagar  Diana Sobreira        Megabyte
# 267  como obter apoio por Telefone sem pagar  Diana Sobreira        Megabyte
# 268  como obter apoio por Telefone sem pagar  Diana Sobreira        Megabyte
# 269  como obter apoio por Telefone sem pagar  Diana Sobreira        Megabyte
#
#                                             Texto_Post   Data_Post  \
# 0    Boa noite,  o meu telefone fixo avariou. Mande...  2018-11-15
# 1    Boa noite,  o meu telefone fixo avariou. Mande...  2018-11-15
# 2    Boa noite,  o meu telefone fixo avariou. Mande...  2018-11-15
# 3    Boa noite,  o meu telefone fixo avariou. Mande...  2018-11-15
# 4    Boa noite,  o meu telefone fixo avariou. Mande...  2018-11-15
# ..                                                 ...         ...
# 265  Tenho o pacote da nos(fibra) ha 15 dias e tira...  2019-07-20
# 266  Tenho o pacote da nos(fibra) ha 15 dias e tira...  2019-07-20
# 267  Tenho o pacote da nos(fibra) ha 15 dias e tira...  2019-07-20
# 268  Tenho o pacote da nos(fibra) ha 15 dias e tira...  2019-07-20
# 269  Tenho o pacote da nos(fibra) ha 15 dias e tira...  2019-07-20
#
#              Likes_Post            Users Class_Users Data_coments  \
# 0       1 pessoa gostou   Elísia Tavares   Yottabyte   2018-11-15
# 1       1 pessoa gostou   Jose Rodrigues   Yottabyte   2018-11-15
# 2       1 pessoa gostou   Elísia Tavares    Kilobyte   2018-11-16
# 3       1 pessoa gostou   Jose Rodrigues        Byte   2018-11-16
# 4       1 pessoa gostou           juli89   Yottabyte   2018-11-16
# ..                  ...              ...         ...          ...
# 265  4 pessoas gostaram   Diana Sobreira        None   2019-07-20
# 266  4 pessoas gostaram   Jose Rodrigues        None   2019-07-20
# 267  4 pessoas gostaram           Ana P.        None   2019-07-20
# 268  4 pessoas gostaram  americoteixeira        None   2021-03-25
# 269  4 pessoas gostaram   Jose Rodrigues        None   2021-03-25
#
#                                                Coments Likes_Coments
# 0    Boa noite,  o meu telefone fixo avariou. Mande...          Like
# 1    Se está dentro da garantia, pode passar por um...          Like
# 2    O telefone, enquanto aparelho, funciono. A NOS...          Like
# 3    Bom dia, então a avaria não é no aparelho mas ...          Like
# 4    @Elísia Tavares já experimentaste desligar as ...          Like
# ..                                                 ...           ...
# 265  Obrigada o serviço depois voltou ao normal pas...          Like
# 266  Diana Sobreira escreveu: Obrigada o serviço de...          Like
# 267  Olá @Diana Sobreira e @Jose Rodrigues ,  O @Jo...          Like
# 268                     Nao tenho wifi não sei porquê.          Like
# 269  americoteixeira escreveu: Nao tenho wifi não s...          Like
#
# [270 rows x 16 columns]

# %%
base
# Out:
#                   Data_recolha        Categoria Empresa   n  \
# 0   2021-03-25 16:44:49.203667  Telecomunicação     NOS   1
# 1   2021-03-25 16:44:49.203667  Telecomunicação     NOS   1
# 2   2021-03-25 16:44:49.203667  Telecomunicação     NOS   1
# 3   2021-03-25 16:44:49.203667  Telecomunicação     NOS   1
# 4   2021-03-25 16:44:49.203667  Telecomunicação     NOS   1
# ..                         ...              ...     ...  ..
# 265 2021-03-25 16:47:19.961270  Telecomunicação     NOS  25
# 266 2021-03-25 16:47:19.961270  Telecomunicação     NOS  25
# 267 2021-03-25 16:47:19.961270  Telecomunicação     NOS  25
# 268 2021-03-25 16:47:19.961270  Telecomunicação     NOS  25
# 269 2021-03-25 16:47:19.961270  Telecomunicação     NOS  25
#
#                                               URL_Post  \
# 0    https://forum.nos.pt/configurar-o-telefone-fix...
# 1    https://forum.nos.pt/configurar-o-telefone-fix...
# 2    https://forum.nos.pt/configurar-o-telefone-fix...
# 3    https://forum.nos.pt/configurar-o-telefone-fix...
# 4    https://forum.nos.pt/configurar-o-telefone-fix...
# ..                                                 ...
# 265  https://forum.nos.pt/ver-televisao-em-casa-5/c...
# 266  https://forum.nos.pt/ver-televisao-em-casa-5/c...
# 267  https://forum.nos.pt/ver-televisao-em-casa-5/c...
# 268  https://forum.nos.pt/ver-televisao-em-casa-5/c...
# 269  https://forum.nos.pt/ver-televisao-em-casa-5/c...
#
#                                   Title_Post       User_Post Class_User_Post  \
# 0                       Avaria telefone fixo  Elísia Tavares       Yottabyte
# 1                       Avaria telefone fixo  Elísia Tavares       Yottabyte
# 2                       Avaria telefone fixo  Elísia Tavares       Yottabyte
# 3                       Avaria telefone fixo  Elísia Tavares       Yottabyte
# 4                       Avaria telefone fixo  Elísia Tavares       Yottabyte
# ..                                       ...             ...             ...
# 265  como obter apoio por Telefone sem pagar  Diana Sobreira        Megabyte
# 266  como obter apoio por Telefone sem pagar  Diana Sobreira        Megabyte
# 267  como obter apoio por Telefone sem pagar  Diana Sobreira        Megabyte
# 268  como obter apoio por Telefone sem pagar  Diana Sobreira        Megabyte
# 269  como obter apoio por Telefone sem pagar  Diana Sobreira        Megabyte
#
#                                             Texto_Post   Data_Post  \
# 0    Boa noite,  o meu telefone fixo avariou. Mande...  2018-11-15
# 1    Boa noite,  o meu telefone fixo avariou. Mande...  2018-11-15
# 2    Boa noite,  o meu telefone fixo avariou. Mande...  2018-11-15
# 3    Boa noite,  o meu telefone fixo avariou. Mande...  2018-11-15
# 4    Boa noite,  o meu telefone fixo avariou. Mande...  2018-11-15
# ..                                                 ...         ...
# 265  Tenho o pacote da nos(fibra) ha 15 dias e tira...  2019-07-20
# 266  Tenho o pacote da nos(fibra) ha 15 dias e tira...  2019-07-20
# 267  Tenho o pacote da nos(fibra) ha 15 dias e tira...  2019-07-20
# 268  Tenho o pacote da nos(fibra) ha 15 dias e tira...  2019-07-20
# 269  Tenho o pacote da nos(fibra) ha 15 dias e tira...  2019-07-20
#
#              Likes_Post            Users Class_Users Data_coments  \
# 0       1 pessoa gostou   Elísia Tavares   Yottabyte   2018-11-15
# 1       1 pessoa gostou   Jose Rodrigues   Yottabyte   2018-11-15
# 2       1 pessoa gostou   Elísia Tavares    Kilobyte   2018-11-16
# 3       1 pessoa gostou   Jose Rodrigues        Byte   2018-11-16
# 4       1 pessoa gostou           juli89   Yottabyte   2018-11-16
# ..                  ...              ...         ...          ...
# 265  4 pessoas gostaram   Diana Sobreira        None   2019-07-20
# 266  4 pessoas gostaram   Jose Rodrigues        None   2019-07-20
# 267  4 pessoas gostaram           Ana P.        None   2019-07-20
# 268  4 pessoas gostaram  americoteixeira        None   2021-03-25
# 269  4 pessoas gostaram   Jose Rodrigues        None   2021-03-25
#
#                                                Coments Likes_Coments
# 0    Boa noite,  o meu telefone fixo avariou. Mande...          Like
# 1    Se está dentro da garantia, pode passar por um...          Like
# 2    O telefone, enquanto aparelho, funciono. A NOS...          Like
# 3    Bom dia, então a avaria não é no aparelho mas ...          Like
# 4    @Elísia Tavares já experimentaste desligar as ...          Like
# ..                                                 ...           ...
# 265  Obrigada o serviço depois voltou ao normal pas...          Like
# 266  Diana Sobreira escreveu: Obrigada o serviço de...          Like
# 267  Olá @Diana Sobreira e @Jose Rodrigues ,  O @Jo...          Like
# 268                     Nao tenho wifi não sei porquê.          Like
# 269  americoteixeira escreveu: Nao tenho wifi não s...          Like
#
# [270 rows x 16 columns]

# %%
base.URL_Post[0]
# Out:
# 'https://forum.nos.pt/configurar-o-telefone-fixo-35/avaria-telefone-fixo-9849'

# %% [markdown]
# ### Export

# %%
writer = pd.ExcelWriter('BASES/NOS_v6.xlsx',
                        engine='xlsxwriter',options={'strings_to_urls': False}) #.format(staName2)
base.to_excel(writer)
writer.close()
